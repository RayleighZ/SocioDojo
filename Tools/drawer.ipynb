# %%
import matplotlib.pyplot as plt
import json
import os

ACCOUNT_PATH = '/home/tione/notebook/rayleighz_prj/SocioDojo/Ckpts/llama3.1_8B_0.5_Fin/Account'

json_list = os.listdir(ACCOUNT_PATH)
json_count = len(json_list)
account_list = []
for i in range(json_count):
    with open(f'{ACCOUNT_PATH}/default-{i}.json', 'r') as f:
        account = json.load(f)
    account_list.append(account['total value'])
print(account_list)
